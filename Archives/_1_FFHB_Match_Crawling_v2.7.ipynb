# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from urllib.request import urlretrieve
import time
import re
import csv
import sqlite3
import glob, os

# %%
# Liste de tous les matchs extraits
lst= glob.glob(".\FDM\*.pdf")
print("Nombre de matchs analysés: ",len(lst))
lst = [l.replace('FDM\\',"").replace('.sqlite','.pdf') for l in lst]
# Out:
# Nombre de matchs analysés:  0

# %%
# install chrome web driver https://sites.google.com/a/chromium.org/chromedriver/downloads
PATH = "C:\Program Files\chromedriver.exe"
driver = webdriver.Chrome(PATH)

# Pointing to the targeted poule
driver.get("https://www.ffhandball.fr/fr/competition/20405#poule-109164")
time.sleep(1)

# Close the window that is opening when opening from chrome machine
Path = '//*[@id="didomi-notice-agree-button"]'
driver.find_element(By.XPATH, Path).click()
time.sleep(1)

# %%
# Sélectionne le championnat et la journée
content = driver.find_element_by_class_name('l-page-content')
content.click()
time.sleep(2)
counter = 0
TXT= list()
ans=input('Entre la premiere journée (incluse) à scraper (par defaut 1):')
if ans=="": j0=1
else: j0=int(ans)
ans=input('Entre la derniere journée (incluse) à scraper (par défaut 22):')
if ans=="": j1=22
else: j1=int(ans)
# Out:
# Entre la premiere journée (incluse) à scraper (par defaut 1):
# Entre la derniere journée (incluse) à scraper (par défaut 22):

# %%
dir=os.path.abspath('.\FDM')

for j in range(j0-1,j1):
    try:
        XPATH = "//*[@class='s-fixtures-calendar-day ' and text()="+str(j+1)+"]"
        journee = driver.find_element_by_xpath(XPATH)
        journee.click()
        time.sleep(2)
    except:
        XPATH = "//*[@class='s-fixtures-calendar-day s-fixtures-calendar-day--current-date' and text()="+str(j+1)+"]"
        journee = driver.find_element_by_xpath(XPATH)
        journee.click()
        time.sleep(2)
    # Affiche le titre et le contenu texte de la page
    text = driver.page_source
    text2=text.split('<div class="s-fixtures-table-row">')
    #
    if counter == 0 :
        print(driver.title)
        Ligue = re.findall('<div class="m-standings__title">(.+?)</div>',text) # Ligue
        print(Ligue[0])
        Poule = re.findall('<span class="js-dropdown__current b-dropdown-custom__button">(.+?)</span>',text) # Poule
        print(Poule[0])
    Periode = re.findall('<div class="s-fixtures-table__title">(.+?)</div>',text) # Date période des journées
    print(Periode)
    #
    for l in text2[1:]:
            m = dict()
            Date = re.findall('<p class="s-fixtures-table-cell-row__date">(.+?)</p>',l) # Date journée
            Match = re.findall('<p class="s-fixtures-table-cell-row__name">(.+?)</p>',l) # Match
            Score = list()
            for i in re.findall('<p class="s-fixtures-table-cell-row__result(.+?)</p>',l):
                Score.append(re.findall('>(.+)',i))
            Infos = re.findall('<p class="s-fixtures-table-cell-list__item">(.+?)</p>',l) # Match
            FDM = re.findall('<a href="(.+?)" class="s-fixtures-table-cell-button" target="_blank">FDM</a>',l) # Lien fichier feuille de match
            title = str(j+1)+"_"+Match[0].replace('/','&')+"-"+Match[1].replace('/','&')+".pdf"
            print(Date, Match,Infos)
            print(FDM,title)
            if (FDM != []) & (title not in lst):
                path = os.path.join(dir,title)
                urlretrieve(FDM[0],path)
                # Enregistre le match sous pdf
            m['Periode']=Periode[0]
            m['Journee']=j+1
            m['Date']=Date[0]
            m['fichier']=title
            m['equipe_dom']=Match[0].replace('/','&')
            m['equipe_ext']=Match[1].replace('/','&')
            m['lieu']=Infos[0]+" "+Infos[1]+" "+Infos[2]
            m['arbitres']=Infos[4]+" "+Infos[5]
            if Score[0][0]=='FO':
                m['score_dom']=-1 # On met un score de -1 si forfait
                m['score_ext']=int(Score[1][0])
                m['diff_buts']=0-int(Score[1][0])
            elif Score[1][0]=='FO':
                m['score_dom']=int(Score[0][0])
                m['score_ext']=-1
                m['diff_buts']=int(Score[0][0])-0
            elif Score[0][0]!='--' and Score[1][0]!='--':
                m['score_dom']=int(Score[0][0])
                m['score_ext']=int(Score[1][0])
                m['diff_buts']=int(Score[0][0])-int(Score[1][0])
            else:
                m['score_dom']=""
                m['score_ext']=""
                m['diff_buts']=""
            TXT.append(m)
    counter = 1
driver.close()
# SAVE in SQLITE Files
conn = sqlite3.connect('Championnat_U18_GrandEst.sqlite')
cur = conn.cursor()
cur.execute('''CREATE TABLE IF NOT EXISTS Matchs  (
    fichier TEXT NOT NULL PRIMARY KEY UNIQUE,
    Journee INTEGER,
    Periode TEXT,
    Date TEXT,
    equipe_dom TEXT,
    equipe_ext TEXT,
    score_dom INTEGER,
    score_ext INTEGER,
    diff_buts INTEGER,
    lieu TEXT,
    arbitres TEXT
    )''')
for m in TXT:
    cur.execute('''INSERT OR REPLACE INTO Matchs (fichier,Journee, Periode, Date, equipe_dom, equipe_ext,score_dom,score_ext,diff_buts,lieu,arbitres)
        VALUES (?,?,?,?,?,?,?,?,?,?,?)''', (m['fichier'],m['Journee'],m['Periode'],m['Date'],m['equipe_dom'],m['equipe_ext'],m['score_dom'],m['score_ext'],m['diff_buts'],m['lieu'],m['arbitres']))
#
conn.commit()
conn.close()
# SAVE IN CSV FILE
#file = "Matchs_"+Ligue[0]+".csv"
#keys = TXT[0].keys()
#a_file = open(file, "w")
##dict_writer = csv.DictWriter(a_file, keys)
#dict_writer.writeheader()
#dict_writer.writerows(TXT)
#a_file.close()
#
print('Task completed ')
# Out:
# Competition
# 56-06 CHAMPIONNAT U18 MASCULIN (L56)
# 56-U18M ELITE
# ['17/09 AU 18/09/2022']
# ['samedi 17 septembre 19H00'] ["ENT RIED'HANDBALL U18M", 'STRASBOURG/SCHILTIGHEIM U18M2'] ['SALLE DU COLLEGE ROMAIN ROLLAND', ' RUE ERCKMANN CHATRIAN', 'ERSTEIN', 'Arbitres', '—', '—']
# [] 1_ENT RIED'HANDBALL U18M-STRASBOURG&SCHILTIGHEIM U18M2.pdf
# ['samedi 17 septembre 17H30'] ['THIONVILLE U18M', 'BASSIN MUSSIPONTAIN U18M'] ['GYMNASE JEAN-PIERRE ADAMS', ' RUE SAINT EXUPERY', 'THIONVILLE', 'Arbitres', '—', '—']
# [] 1_THIONVILLE U18M-BASSIN MUSSIPONTAIN U18M.pdf
# ['dimanche 18 septembre 14H00'] ['ENT MULHOUSE ACADEMIE U18M2', 'HOCHFELDEN/DETTWILLER U18M'] ['ANDRE ERBLAND', '50  BD PRESIDENT ROOSEVELT', 'MULHOUSE', 'Arbitres', '—', '—']
# [] 1_ENT MULHOUSE ACADEMIE U18M2-HOCHFELDEN&DETTWILLER U18M.pdf
# ['dimanche 18 septembre 14H00'] ['METZ U18M', 'LINGOLSHEIM'] ['GYMNASE DU TECHNOPOLE', '5  BOULEVARD ARAGO', 'METZ', 'Arbitres', '—', '—']
# [] 1_METZ U18M-LINGOLSHEIM.pdf
# ['dimanche 18 septembre 14H00'] ['NANCY U18M2', 'SELESTAT U18M2'] ['GYMNASE PROVENCAL', '69 QUAI RENE 2', 'NANCY', 'Arbitres', '—', '—']
# [] 1_NANCY U18M2-SELESTAT U18M2.pdf
# ['—'] ['COLMAR HC U18M', 'EPINAL U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 1_COLMAR HC U18M-EPINAL U18M.pdf
# ['24/09 AU 25/09/2022']
# ['samedi 24 septembre 18H00'] ['STRASBOURG/SCHILTIGHEIM U18M2', 'THIONVILLE U18M'] ['GYMNASE DES MALTERIES', '49  RUE DES MALTERIES', 'SCHILTIGHEIM', 'Arbitres', '—', '—']
# [] 2_STRASBOURG&SCHILTIGHEIM U18M2-THIONVILLE U18M.pdf
# ['samedi 24 septembre 16H30'] ['HOCHFELDEN/DETTWILLER U18M', "ENT RIED'HANDBALL U18M"] ['COMPLEXE SPORTIF DE HOCHFELDEN', '1  RUE DES 4 VENTS', 'HOCHFELDEN', 'Arbitres', '—', '—']
# [] 2_HOCHFELDEN&DETTWILLER U18M-ENT RIED'HANDBALL U18M.pdf
# ['samedi 24 septembre 16H00'] ['BASSIN MUSSIPONTAIN U18M', 'EPINAL U18M'] ['CHARLES ROTH', ' RUE JACQUES ANQUETIL', 'DIEULOUARD', 'Arbitres', '—', '—']
# [] 2_BASSIN MUSSIPONTAIN U18M-EPINAL U18M.pdf
# ['dimanche 25 septembre 16H00'] ['LINGOLSHEIM', 'ENT MULHOUSE ACADEMIE U18M2'] ['GYMNASE COLETTE BESSON', '30 MARIA CALAS', 'LINGOLSHEIM', 'Arbitres', '—', '—']
# [] 2_LINGOLSHEIM-ENT MULHOUSE ACADEMIE U18M2.pdf
# ['samedi 24 septembre 18H00'] ['COLMAR HC U18M', 'NANCY U18M2'] ['MONTAGNE VERTE', ' PLACE DE LA MONTAGNE VERTE', 'COLMAR', 'Arbitres', '—', '—']
# [] 2_COLMAR HC U18M-NANCY U18M2.pdf
# ['dimanche 25 septembre 16H00'] ['SELESTAT U18M2', 'METZ U18M'] ['COSEC EUGENE GRIESMAR', ' QUAI ALBRECHT', 'SELESTAT', 'Arbitres', '—', '—']
# [] 2_SELESTAT U18M2-METZ U18M.pdf
# ['01/10 AU 02/10/2022']
# ['samedi 1 octobre 18H00'] ['STRASBOURG/SCHILTIGHEIM U18M2', 'HOCHFELDEN/DETTWILLER U18M'] ['GYMNASE DES MALTERIES', '49  RUE DES MALTERIES', 'SCHILTIGHEIM', 'Arbitres', '—', '—']
# [] 3_STRASBOURG&SCHILTIGHEIM U18M2-HOCHFELDEN&DETTWILLER U18M.pdf
# ['—'] ['EPINAL U18M', 'THIONVILLE U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 3_EPINAL U18M-THIONVILLE U18M.pdf
# ['dimanche 2 octobre 14H00'] ["ENT RIED'HANDBALL U18M", 'LINGOLSHEIM'] ['HALL DES SPORTS', " RUE D'ETTENHEIM", 'BENFELD', 'Arbitres', '—', '—']
# [] 3_ENT RIED'HANDBALL U18M-LINGOLSHEIM.pdf
# ['samedi 1 octobre 18H00'] ['NANCY U18M2', 'BASSIN MUSSIPONTAIN U18M'] ['GYMNASE PROVENCAL', '69 QUAI RENE 2', 'NANCY', 'Arbitres', '—', '—']
# [] 3_NANCY U18M2-BASSIN MUSSIPONTAIN U18M.pdf
# ['samedi 1 octobre 14H00'] ['ENT MULHOUSE ACADEMIE U18M2', 'SELESTAT U18M2'] ['COMPLEXE SPORTIF', ' RUE DE LA FORET NOIRE', 'RIXHEIM', 'Arbitres', '—', '—']
# [] 3_ENT MULHOUSE ACADEMIE U18M2-SELESTAT U18M2.pdf
# ['samedi 1 octobre 16H00'] ['METZ U18M', 'COLMAR HC U18M'] ['GYMNASE DU TECHNOPOLE', '5  BOULEVARD ARAGO', 'METZ', 'Arbitres', '—', '—']
# [] 3_METZ U18M-COLMAR HC U18M.pdf
# ['08/10 AU 09/10/2022']
# ['—'] ['EPINAL U18M', 'STRASBOURG/SCHILTIGHEIM U18M2'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 4_EPINAL U18M-STRASBOURG&SCHILTIGHEIM U18M2.pdf
# ['—'] ['LINGOLSHEIM', 'HOCHFELDEN/DETTWILLER U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 4_LINGOLSHEIM-HOCHFELDEN&DETTWILLER U18M.pdf
# ['—'] ['THIONVILLE U18M', 'NANCY U18M2'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 4_THIONVILLE U18M-NANCY U18M2.pdf
# ['—'] ['SELESTAT U18M2', "ENT RIED'HANDBALL U18M"] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 4_SELESTAT U18M2-ENT RIED'HANDBALL U18M.pdf
# ['—'] ['BASSIN MUSSIPONTAIN U18M', 'METZ U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 4_BASSIN MUSSIPONTAIN U18M-METZ U18M.pdf
# ['dimanche 9 octobre 14H00'] ['COLMAR HC U18M', 'ENT MULHOUSE ACADEMIE U18M2'] ['MONTAGNE VERTE', ' PLACE DE LA MONTAGNE VERTE', 'COLMAR', 'Arbitres', '—', '—']
# [] 4_COLMAR HC U18M-ENT MULHOUSE ACADEMIE U18M2.pdf
# ['15/10 AU 16/10/2022']
# ['samedi 15 octobre 18H00'] ['STRASBOURG/SCHILTIGHEIM U18M2', 'LINGOLSHEIM'] ['GYMNASE DES MALTERIES', '49  RUE DES MALTERIES', 'SCHILTIGHEIM', 'Arbitres', '—', '—']
# [] 5_STRASBOURG&SCHILTIGHEIM U18M2-LINGOLSHEIM.pdf
# ['—'] ['NANCY U18M2', 'EPINAL U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 5_NANCY U18M2-EPINAL U18M.pdf
# ['samedi 15 octobre 18H30'] ['HOCHFELDEN/DETTWILLER U18M', 'SELESTAT U18M2'] ['COMPLEXE SPORTIF DE HOCHFELDEN', '1  RUE DES 4 VENTS', 'HOCHFELDEN', 'Arbitres', '—', '—']
# [] 5_HOCHFELDEN&DETTWILLER U18M-SELESTAT U18M2.pdf
# ['—'] ['METZ U18M', 'THIONVILLE U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 5_METZ U18M-THIONVILLE U18M.pdf
# ['—'] ["ENT RIED'HANDBALL U18M", 'COLMAR HC U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 5_ENT RIED'HANDBALL U18M-COLMAR HC U18M.pdf
# ['dimanche 16 octobre 16H00'] ['ENT MULHOUSE ACADEMIE U18M2', 'BASSIN MUSSIPONTAIN U18M'] ['COMPLEXE SPORTIF', ' RUE DE LA FORET NOIRE', 'RIXHEIM', 'Arbitres', '—', '—']
# [] 5_ENT MULHOUSE ACADEMIE U18M2-BASSIN MUSSIPONTAIN U18M.pdf
# ['22/10 AU 23/10/2022']
# ['samedi 22 octobre 18H00'] ['NANCY U18M2', 'STRASBOURG/SCHILTIGHEIM U18M2'] ['GYMNASE PROVENCAL', '69 QUAI RENE 2', 'NANCY', 'Arbitres', '—', '—']
# [] 6_NANCY U18M2-STRASBOURG&SCHILTIGHEIM U18M2.pdf
# ['—'] ['SELESTAT U18M2', 'LINGOLSHEIM'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 6_SELESTAT U18M2-LINGOLSHEIM.pdf
# ['—'] ['EPINAL U18M', 'METZ U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 6_EPINAL U18M-METZ U18M.pdf
# ['samedi 22 octobre 18H00'] ['COLMAR HC U18M', 'HOCHFELDEN/DETTWILLER U18M'] ['MONTAGNE VERTE', ' PLACE DE LA MONTAGNE VERTE', 'COLMAR', 'Arbitres', '—', '—']
# [] 6_COLMAR HC U18M-HOCHFELDEN&DETTWILLER U18M.pdf
# ['—'] ['THIONVILLE U18M', 'ENT MULHOUSE ACADEMIE U18M2'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 6_THIONVILLE U18M-ENT MULHOUSE ACADEMIE U18M2.pdf
# ['—'] ['BASSIN MUSSIPONTAIN U18M', "ENT RIED'HANDBALL U18M"] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 6_BASSIN MUSSIPONTAIN U18M-ENT RIED'HANDBALL U18M.pdf
# ['19/11 AU 20/11/2022']
# ['samedi 19 novembre 18H00'] ['STRASBOURG/SCHILTIGHEIM U18M2', 'SELESTAT U18M2'] ['GYMNASE DES MALTERIES', '49  RUE DES MALTERIES', 'SCHILTIGHEIM', 'Arbitres', '—', '—']
# [] 7_STRASBOURG&SCHILTIGHEIM U18M2-SELESTAT U18M2.pdf
# ['—'] ['METZ U18M', 'NANCY U18M2'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 7_METZ U18M-NANCY U18M2.pdf
# ['—'] ['LINGOLSHEIM', 'COLMAR HC U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 7_LINGOLSHEIM-COLMAR HC U18M.pdf
# ['samedi 19 novembre 18H30'] ['ENT MULHOUSE ACADEMIE U18M2', 'EPINAL U18M'] ['ANDRE ERBLAND', '50  BD PRESIDENT ROOSEVELT', 'MULHOUSE', 'Arbitres', '—', '—']
# [] 7_ENT MULHOUSE ACADEMIE U18M2-EPINAL U18M.pdf
# ['—'] ['HOCHFELDEN/DETTWILLER U18M', 'BASSIN MUSSIPONTAIN U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 7_HOCHFELDEN&DETTWILLER U18M-BASSIN MUSSIPONTAIN U18M.pdf
# ['—'] ["ENT RIED'HANDBALL U18M", 'THIONVILLE U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 7_ENT RIED'HANDBALL U18M-THIONVILLE U18M.pdf
# ['26/11 AU 27/11/2022']
# ['—'] ['METZ U18M', 'STRASBOURG/SCHILTIGHEIM U18M2'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 8_METZ U18M-STRASBOURG&SCHILTIGHEIM U18M2.pdf
# ['dimanche 27 novembre 14H00'] ['COLMAR HC U18M', 'SELESTAT U18M2'] ['MONTAGNE VERTE', ' PLACE DE LA MONTAGNE VERTE', 'COLMAR', 'Arbitres', '—', '—']
# [] 8_COLMAR HC U18M-SELESTAT U18M2.pdf
# ['—'] ['NANCY U18M2', 'ENT MULHOUSE ACADEMIE U18M2'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 8_NANCY U18M2-ENT MULHOUSE ACADEMIE U18M2.pdf
# ['—'] ['BASSIN MUSSIPONTAIN U18M', 'LINGOLSHEIM'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 8_BASSIN MUSSIPONTAIN U18M-LINGOLSHEIM.pdf
# ['—'] ['EPINAL U18M', "ENT RIED'HANDBALL U18M"] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 8_EPINAL U18M-ENT RIED'HANDBALL U18M.pdf
# ['—'] ['THIONVILLE U18M', 'HOCHFELDEN/DETTWILLER U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 8_THIONVILLE U18M-HOCHFELDEN&DETTWILLER U18M.pdf
# ['10/12 AU 11/12/2022']
# ['samedi 10 décembre 14H30'] ['STRASBOURG/SCHILTIGHEIM U18M2', 'COLMAR HC U18M'] ['GYMNASE DES MALTERIES', '49  RUE DES MALTERIES', 'SCHILTIGHEIM', 'Arbitres', '—', '—']
# [] 9_STRASBOURG&SCHILTIGHEIM U18M2-COLMAR HC U18M.pdf
# ['samedi 10 décembre 16H00'] ['ENT MULHOUSE ACADEMIE U18M2', 'METZ U18M'] ['COMPLEXE SPORTIF', ' RUE DE LA FORET NOIRE', 'RIXHEIM', 'Arbitres', '—', '—']
# [] 9_ENT MULHOUSE ACADEMIE U18M2-METZ U18M.pdf
# ['—'] ['SELESTAT U18M2', 'BASSIN MUSSIPONTAIN U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 9_SELESTAT U18M2-BASSIN MUSSIPONTAIN U18M.pdf
# ['—'] ["ENT RIED'HANDBALL U18M", 'NANCY U18M2'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 9_ENT RIED'HANDBALL U18M-NANCY U18M2.pdf
# ['—'] ['LINGOLSHEIM', 'THIONVILLE U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 9_LINGOLSHEIM-THIONVILLE U18M.pdf
# ['—'] ['HOCHFELDEN/DETTWILLER U18M', 'EPINAL U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 9_HOCHFELDEN&DETTWILLER U18M-EPINAL U18M.pdf
# ['14/01 AU 15/01/2023']
# ['—'] ['ENT MULHOUSE ACADEMIE U18M2', 'STRASBOURG/SCHILTIGHEIM U18M2'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 10_ENT MULHOUSE ACADEMIE U18M2-STRASBOURG&SCHILTIGHEIM U18M2.pdf
# ['—'] ['BASSIN MUSSIPONTAIN U18M', 'COLMAR HC U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 10_BASSIN MUSSIPONTAIN U18M-COLMAR HC U18M.pdf
# ['—'] ['METZ U18M', "ENT RIED'HANDBALL U18M"] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 10_METZ U18M-ENT RIED'HANDBALL U18M.pdf
# ['—'] ['THIONVILLE U18M', 'SELESTAT U18M2'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 10_THIONVILLE U18M-SELESTAT U18M2.pdf
# ['—'] ['NANCY U18M2', 'HOCHFELDEN/DETTWILLER U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 10_NANCY U18M2-HOCHFELDEN&DETTWILLER U18M.pdf
# ['—'] ['EPINAL U18M', 'LINGOLSHEIM'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 10_EPINAL U18M-LINGOLSHEIM.pdf
# ['21/01 AU 22/01/2023']
# ['—'] ['STRASBOURG/SCHILTIGHEIM U18M2', 'BASSIN MUSSIPONTAIN U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 11_STRASBOURG&SCHILTIGHEIM U18M2-BASSIN MUSSIPONTAIN U18M.pdf
# ['—'] ["ENT RIED'HANDBALL U18M", 'ENT MULHOUSE ACADEMIE U18M2'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 11_ENT RIED'HANDBALL U18M-ENT MULHOUSE ACADEMIE U18M2.pdf
# ['samedi 21 janvier 17H30'] ['COLMAR HC U18M', 'THIONVILLE U18M'] ['MONTAGNE VERTE', ' PLACE DE LA MONTAGNE VERTE', 'COLMAR', 'Arbitres', '—', '—']
# [] 11_COLMAR HC U18M-THIONVILLE U18M.pdf
# ['—'] ['HOCHFELDEN/DETTWILLER U18M', 'METZ U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 11_HOCHFELDEN&DETTWILLER U18M-METZ U18M.pdf
# ['—'] ['SELESTAT U18M2', 'EPINAL U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 11_SELESTAT U18M2-EPINAL U18M.pdf
# ['—'] ['LINGOLSHEIM', 'NANCY U18M2'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 11_LINGOLSHEIM-NANCY U18M2.pdf
# ['28/01 AU 29/01/2023']
# ['—'] ['STRASBOURG/SCHILTIGHEIM U18M2', "ENT RIED'HANDBALL U18M"] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 12_STRASBOURG&SCHILTIGHEIM U18M2-ENT RIED'HANDBALL U18M.pdf
# ['—'] ['BASSIN MUSSIPONTAIN U18M', 'THIONVILLE U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 12_BASSIN MUSSIPONTAIN U18M-THIONVILLE U18M.pdf
# ['—'] ['HOCHFELDEN/DETTWILLER U18M', 'ENT MULHOUSE ACADEMIE U18M2'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 12_HOCHFELDEN&DETTWILLER U18M-ENT MULHOUSE ACADEMIE U18M2.pdf
# ['—'] ['LINGOLSHEIM', 'METZ U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 12_LINGOLSHEIM-METZ U18M.pdf
# ['—'] ['SELESTAT U18M2', 'NANCY U18M2'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 12_SELESTAT U18M2-NANCY U18M2.pdf
# ['—'] ['EPINAL U18M', 'COLMAR HC U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 12_EPINAL U18M-COLMAR HC U18M.pdf
# ['04/02 AU 05/02/2023']
# ['—'] ['THIONVILLE U18M', 'STRASBOURG/SCHILTIGHEIM U18M2'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 13_THIONVILLE U18M-STRASBOURG&SCHILTIGHEIM U18M2.pdf
# ['—'] ["ENT RIED'HANDBALL U18M", 'HOCHFELDEN/DETTWILLER U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 13_ENT RIED'HANDBALL U18M-HOCHFELDEN&DETTWILLER U18M.pdf
# ['—'] ['EPINAL U18M', 'BASSIN MUSSIPONTAIN U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 13_EPINAL U18M-BASSIN MUSSIPONTAIN U18M.pdf
# ['—'] ['ENT MULHOUSE ACADEMIE U18M2', 'LINGOLSHEIM'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 13_ENT MULHOUSE ACADEMIE U18M2-LINGOLSHEIM.pdf
# ['—'] ['NANCY U18M2', 'COLMAR HC U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 13_NANCY U18M2-COLMAR HC U18M.pdf
# ['—'] ['METZ U18M', 'SELESTAT U18M2'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 13_METZ U18M-SELESTAT U18M2.pdf
# ['11/02 AU 12/02/2023']
# ['—'] ['HOCHFELDEN/DETTWILLER U18M', 'STRASBOURG/SCHILTIGHEIM U18M2'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 14_HOCHFELDEN&DETTWILLER U18M-STRASBOURG&SCHILTIGHEIM U18M2.pdf
# ['—'] ['THIONVILLE U18M', 'EPINAL U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 14_THIONVILLE U18M-EPINAL U18M.pdf
# ['—'] ['LINGOLSHEIM', "ENT RIED'HANDBALL U18M"] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 14_LINGOLSHEIM-ENT RIED'HANDBALL U18M.pdf
# ['—'] ['BASSIN MUSSIPONTAIN U18M', 'NANCY U18M2'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 14_BASSIN MUSSIPONTAIN U18M-NANCY U18M2.pdf
# ['—'] ['SELESTAT U18M2', 'ENT MULHOUSE ACADEMIE U18M2'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 14_SELESTAT U18M2-ENT MULHOUSE ACADEMIE U18M2.pdf
# ['samedi 11 février 17H30'] ['COLMAR HC U18M', 'METZ U18M'] ['MONTAGNE VERTE', ' PLACE DE LA MONTAGNE VERTE', 'COLMAR', 'Arbitres', '—', '—']
# [] 14_COLMAR HC U18M-METZ U18M.pdf
# ['04/03 AU 05/03/2023']
# ['—'] ['STRASBOURG/SCHILTIGHEIM U18M2', 'EPINAL U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 15_STRASBOURG&SCHILTIGHEIM U18M2-EPINAL U18M.pdf
# ['—'] ['HOCHFELDEN/DETTWILLER U18M', 'LINGOLSHEIM'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 15_HOCHFELDEN&DETTWILLER U18M-LINGOLSHEIM.pdf
# ['—'] ['NANCY U18M2', 'THIONVILLE U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 15_NANCY U18M2-THIONVILLE U18M.pdf
# ['—'] ["ENT RIED'HANDBALL U18M", 'SELESTAT U18M2'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 15_ENT RIED'HANDBALL U18M-SELESTAT U18M2.pdf
# ['—'] ['METZ U18M', 'BASSIN MUSSIPONTAIN U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 15_METZ U18M-BASSIN MUSSIPONTAIN U18M.pdf
# ['—'] ['ENT MULHOUSE ACADEMIE U18M2', 'COLMAR HC U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 15_ENT MULHOUSE ACADEMIE U18M2-COLMAR HC U18M.pdf
# ['11/03 AU 12/03/2023']
# ['—'] ['LINGOLSHEIM', 'STRASBOURG/SCHILTIGHEIM U18M2'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 16_LINGOLSHEIM-STRASBOURG&SCHILTIGHEIM U18M2.pdf
# ['—'] ['EPINAL U18M', 'NANCY U18M2'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 16_EPINAL U18M-NANCY U18M2.pdf
# ['—'] ['SELESTAT U18M2', 'HOCHFELDEN/DETTWILLER U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 16_SELESTAT U18M2-HOCHFELDEN&DETTWILLER U18M.pdf
# ['—'] ['THIONVILLE U18M', 'METZ U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 16_THIONVILLE U18M-METZ U18M.pdf
# ['dimanche 12 mars 14H00'] ['COLMAR HC U18M', "ENT RIED'HANDBALL U18M"] ['MONTAGNE VERTE', ' PLACE DE LA MONTAGNE VERTE', 'COLMAR', 'Arbitres', '—', '—']
# [] 16_COLMAR HC U18M-ENT RIED'HANDBALL U18M.pdf
# ['—'] ['BASSIN MUSSIPONTAIN U18M', 'ENT MULHOUSE ACADEMIE U18M2'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 16_BASSIN MUSSIPONTAIN U18M-ENT MULHOUSE ACADEMIE U18M2.pdf
# ['18/03 AU 19/03/2023']
# ['—'] ['STRASBOURG/SCHILTIGHEIM U18M2', 'NANCY U18M2'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 17_STRASBOURG&SCHILTIGHEIM U18M2-NANCY U18M2.pdf
# ['—'] ['LINGOLSHEIM', 'SELESTAT U18M2'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 17_LINGOLSHEIM-SELESTAT U18M2.pdf
# ['—'] ['METZ U18M', 'EPINAL U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 17_METZ U18M-EPINAL U18M.pdf
# ['—'] ['HOCHFELDEN/DETTWILLER U18M', 'COLMAR HC U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 17_HOCHFELDEN&DETTWILLER U18M-COLMAR HC U18M.pdf
# ['—'] ['ENT MULHOUSE ACADEMIE U18M2', 'THIONVILLE U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 17_ENT MULHOUSE ACADEMIE U18M2-THIONVILLE U18M.pdf
# ['—'] ["ENT RIED'HANDBALL U18M", 'BASSIN MUSSIPONTAIN U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 17_ENT RIED'HANDBALL U18M-BASSIN MUSSIPONTAIN U18M.pdf
# ['01/04 AU 02/04/2023']
# ['—'] ['SELESTAT U18M2', 'STRASBOURG/SCHILTIGHEIM U18M2'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 18_SELESTAT U18M2-STRASBOURG&SCHILTIGHEIM U18M2.pdf
# ['—'] ['NANCY U18M2', 'METZ U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 18_NANCY U18M2-METZ U18M.pdf
# ['samedi 1 avril 16H30'] ['COLMAR HC U18M', 'LINGOLSHEIM'] ['MONTAGNE VERTE', ' PLACE DE LA MONTAGNE VERTE', 'COLMAR', 'Arbitres', '—', '—']
# [] 18_COLMAR HC U18M-LINGOLSHEIM.pdf
# ['—'] ['EPINAL U18M', 'ENT MULHOUSE ACADEMIE U18M2'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 18_EPINAL U18M-ENT MULHOUSE ACADEMIE U18M2.pdf
# ['—'] ['BASSIN MUSSIPONTAIN U18M', 'HOCHFELDEN/DETTWILLER U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 18_BASSIN MUSSIPONTAIN U18M-HOCHFELDEN&DETTWILLER U18M.pdf
# ['—'] ['THIONVILLE U18M', "ENT RIED'HANDBALL U18M"] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 18_THIONVILLE U18M-ENT RIED'HANDBALL U18M.pdf
# ['15/04 AU 16/04/2023']
# ['—'] ['STRASBOURG/SCHILTIGHEIM U18M2', 'METZ U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 19_STRASBOURG&SCHILTIGHEIM U18M2-METZ U18M.pdf
# ['—'] ['SELESTAT U18M2', 'COLMAR HC U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 19_SELESTAT U18M2-COLMAR HC U18M.pdf
# ['—'] ['ENT MULHOUSE ACADEMIE U18M2', 'NANCY U18M2'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 19_ENT MULHOUSE ACADEMIE U18M2-NANCY U18M2.pdf
# ['—'] ['LINGOLSHEIM', 'BASSIN MUSSIPONTAIN U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 19_LINGOLSHEIM-BASSIN MUSSIPONTAIN U18M.pdf
# ['—'] ["ENT RIED'HANDBALL U18M", 'EPINAL U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 19_ENT RIED'HANDBALL U18M-EPINAL U18M.pdf
# ['—'] ['HOCHFELDEN/DETTWILLER U18M', 'THIONVILLE U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 19_HOCHFELDEN&DETTWILLER U18M-THIONVILLE U18M.pdf
# ['06/05 AU 07/05/2023']
# ['dimanche 7 mai 14H00'] ['COLMAR HC U18M', 'STRASBOURG/SCHILTIGHEIM U18M2'] ['MONTAGNE VERTE', ' PLACE DE LA MONTAGNE VERTE', 'COLMAR', 'Arbitres', '—', '—']
# [] 20_COLMAR HC U18M-STRASBOURG&SCHILTIGHEIM U18M2.pdf
# ['—'] ['METZ U18M', 'ENT MULHOUSE ACADEMIE U18M2'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 20_METZ U18M-ENT MULHOUSE ACADEMIE U18M2.pdf
# ['—'] ['BASSIN MUSSIPONTAIN U18M', 'SELESTAT U18M2'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 20_BASSIN MUSSIPONTAIN U18M-SELESTAT U18M2.pdf
# ['—'] ['NANCY U18M2', "ENT RIED'HANDBALL U18M"] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 20_NANCY U18M2-ENT RIED'HANDBALL U18M.pdf
# ['—'] ['THIONVILLE U18M', 'LINGOLSHEIM'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 20_THIONVILLE U18M-LINGOLSHEIM.pdf
# ['—'] ['EPINAL U18M', 'HOCHFELDEN/DETTWILLER U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 20_EPINAL U18M-HOCHFELDEN&DETTWILLER U18M.pdf
# ['13/05 AU 14/05/2023']
# ['—'] ['STRASBOURG/SCHILTIGHEIM U18M2', 'ENT MULHOUSE ACADEMIE U18M2'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 21_STRASBOURG&SCHILTIGHEIM U18M2-ENT MULHOUSE ACADEMIE U18M2.pdf
# ['samedi 13 mai 18H00'] ['COLMAR HC U18M', 'BASSIN MUSSIPONTAIN U18M'] ['MONTAGNE VERTE', ' PLACE DE LA MONTAGNE VERTE', 'COLMAR', 'Arbitres', '—', '—']
# [] 21_COLMAR HC U18M-BASSIN MUSSIPONTAIN U18M.pdf
# ['—'] ["ENT RIED'HANDBALL U18M", 'METZ U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 21_ENT RIED'HANDBALL U18M-METZ U18M.pdf
# ['—'] ['SELESTAT U18M2', 'THIONVILLE U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 21_SELESTAT U18M2-THIONVILLE U18M.pdf
# ['—'] ['HOCHFELDEN/DETTWILLER U18M', 'NANCY U18M2'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 21_HOCHFELDEN&DETTWILLER U18M-NANCY U18M2.pdf
# ['—'] ['LINGOLSHEIM', 'EPINAL U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 21_LINGOLSHEIM-EPINAL U18M.pdf
# ['27/05 AU 28/05/2023']
# ['—'] ['BASSIN MUSSIPONTAIN U18M', 'STRASBOURG/SCHILTIGHEIM U18M2'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 22_BASSIN MUSSIPONTAIN U18M-STRASBOURG&SCHILTIGHEIM U18M2.pdf
# ['—'] ['ENT MULHOUSE ACADEMIE U18M2', "ENT RIED'HANDBALL U18M"] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 22_ENT MULHOUSE ACADEMIE U18M2-ENT RIED'HANDBALL U18M.pdf
# ['—'] ['THIONVILLE U18M', 'COLMAR HC U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 22_THIONVILLE U18M-COLMAR HC U18M.pdf
# ['—'] ['METZ U18M', 'HOCHFELDEN/DETTWILLER U18M'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 22_METZ U18M-HOCHFELDEN&DETTWILLER U18M.pdf
# ['—'] ['EPINAL U18M', 'SELESTAT U18M2'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 22_EPINAL U18M-SELESTAT U18M2.pdf
# ['—'] ['NANCY U18M2', 'LINGOLSHEIM'] ['—', '—', '—', 'Arbitres', '—', '—']
# [] 22_NANCY U18M2-LINGOLSHEIM.pdf
# Task completed
