# %%
import cv2 as cv
import glob, os
from datetime import datetime,timedelta
import re
import pandas as pd
import sqlite3

# %% [markdown]
# # Load Match

# %%
championnat =[]
conn = sqlite3.connect('Championnat_U18_GrandEst.sqlite')
cur = conn.cursor()
cur.execute('SELECT * FROM Championnat ')  #WHERE Joueur = ? ', ('MORANDanthony',)
rows = cur.fetchall()
for row in rows:
    line ={}
    line['fichier']= row[1]
    line['Journée'] = row[2]
    line['equipe_dom']=row[3]
    line['equipe_ext']=row[4]
    line['Min']=row[5]
    line['Sec']=row[6]
    line['score_dom']=row[7]
    line['score_ext']=row[8]
    line['Action'] =row[9]
    line['Action_equipe'] =row[10]
    line['Joueur']=row[12]
    championnat.append(line)
conn.close()

# %%
print("Nombre d'actions du championnat:",len(championnat))
# Out:
# Nombre d'actions du championnat: 4022

# %%
df = pd.DataFrame(championnat)
df['Min']=df['Min'].astype(int)
df['Sec']=df['Sec'].astype(int)
df['Temps']=df['Min']+df['Sec']/60

# %%
df['fichier'].unique()
# Out:
# array(['1_COLMAR HC U18M-EPINAL U18M.pdf',
#        "1_ENT RIED'HANDBALL U18M-STRASBOURG&SCHILTIGHEIM U18M2.pdf",
#        '1_THIONVILLE U18M-BASSIN MUSSIPONTAIN U18M.pdf',
#        '1_ENT MULHOUSE ACADEMIE U18M2-HOCHFELDEN&DETTWILLER U18M.pdf',
#        '1_METZ U18M-LINGOLSHEIM.pdf', '1_NANCY U18M2-SELESTAT U18M2.pdf',
#        '2_BASSIN MUSSIPONTAIN U18M-EPINAL U18M.pdf',
#        '2_COLMAR HC U18M-NANCY U18M2.pdf',
#        "2_HOCHFELDEN&DETTWILLER U18M-ENT RIED'HANDBALL U18M.pdf",
#        '2_STRASBOURG&SCHILTIGHEIM U18M2-THIONVILLE U18M.pdf',
#        '2_LINGOLSHEIM-ENT MULHOUSE ACADEMIE U18M2.pdf',
#        '2_SELESTAT U18M2-METZ U18M.pdf',
#        '3_ENT MULHOUSE ACADEMIE U18M2-SELESTAT U18M2.pdf',
#        '3_EPINAL U18M-THIONVILLE U18M.pdf',
#        '3_METZ U18M-COLMAR HC U18M.pdf',
#        '3_STRASBOURG&SCHILTIGHEIM U18M2-HOCHFELDEN&DETTWILLER U18M.pdf',
#        "3_ENT RIED'HANDBALL U18M-LINGOLSHEIM.pdf",
#        '3_NANCY U18M2-BASSIN MUSSIPONTAIN U18M.pdf',
#        '4_BASSIN MUSSIPONTAIN U18M-METZ U18M.pdf',
#        '4_COLMAR HC U18M-ENT MULHOUSE ACADEMIE U18M2.pdf',
#        '4_EPINAL U18M-STRASBOURG&SCHILTIGHEIM U18M2.pdf',
#        '4_LINGOLSHEIM-HOCHFELDEN&DETTWILLER U18M.pdf',
#        "4_SELESTAT U18M2-ENT RIED'HANDBALL U18M.pdf",
#        '4_THIONVILLE U18M-NANCY U18M2.pdf',
#        "5_ENT RIED'HANDBALL U18M-COLMAR HC U18M.pdf",
#        '5_HOCHFELDEN&DETTWILLER U18M-SELESTAT U18M2.pdf',
#        '5_METZ U18M-THIONVILLE U18M.pdf', '5_NANCY U18M2-EPINAL U18M.pdf',
#        '5_STRASBOURG&SCHILTIGHEIM U18M2-LINGOLSHEIM.pdf'], dtype=object)

# %%
match_sélectionné = '5_NANCY U18M2-EPINAL U18M.pdf'
df_m=df[df['fichier']==match_sélectionné].sort_values(by='Temps')
df_m['Full_Action']=df_m.apply(lambda row: f'{row.Action} {row.Joueur}', axis=1)
# eq_dom = df_m['equipe_dom'].unique()[0]
# eq_ext = df_m['equipe_ext'].unique()[0]
# for i,l in df_m.iterrows():
#     if l.Action == "TempsMortd'EquipeVisiteur": df_m.loc[i,'Action_equipe']=eq_ext
#     if l.Action == "TempsMortd'EquipeRecevant": df_m.loc[i,'Action_equipe']=eq_dom
#     if l.Action_equipe == eq_dom: df_m.loc[i,'Score_action_equipe']=l.score_dom
#     elif l.Action_equipe == eq_ext: df_m.loc[i,'Score_action_equipe']=l.score_ext

# %%
df_m
# Out:
#                             fichier  Journée   equipe_dom   equipe_ext  Min  \
# 3768  5_NANCY U18M2-EPINAL U18M.pdf        5  NANCY U18M2  EPINAL U18M    0
# 3770  5_NANCY U18M2-EPINAL U18M.pdf        5  NANCY U18M2  EPINAL U18M    0
# 3772  5_NANCY U18M2-EPINAL U18M.pdf        5  NANCY U18M2  EPINAL U18M    1
# 3774  5_NANCY U18M2-EPINAL U18M.pdf        5  NANCY U18M2  EPINAL U18M    1
# 3776  5_NANCY U18M2-EPINAL U18M.pdf        5  NANCY U18M2  EPINAL U18M    3
# ...                             ...      ...          ...          ...  ...
# 3869  5_NANCY U18M2-EPINAL U18M.pdf        5  NANCY U18M2  EPINAL U18M   58
# 3870  5_NANCY U18M2-EPINAL U18M.pdf        5  NANCY U18M2  EPINAL U18M   59
# 3871  5_NANCY U18M2-EPINAL U18M.pdf        5  NANCY U18M2  EPINAL U18M   59
# 3872  5_NANCY U18M2-EPINAL U18M.pdf        5  NANCY U18M2  EPINAL U18M   60
# 3873  5_NANCY U18M2-EPINAL U18M.pdf        5  NANCY U18M2  EPINAL U18M   60
#
#       Sec  score_dom  score_ext                     Action Action_equipe  \
# 3768   28          0          1                        But   EPINAL U18M
# 3770   59          1          1                        But   NANCY U18M2
# 3772   31          1          2                        But   EPINAL U18M
# 3774   58          2          2                        But   NANCY U18M2
# 3776   11          3          2                        But   NANCY U18M2
# ...   ...        ...        ...                        ...           ...
# 3869   34         19         22  TempsMortd'EquipeVisiteur            NA
# 3870   20         20         22                        But   NANCY U18M2
# 3871   48         20         23                        But   EPINAL U18M
# 3872    0         20         23  DisqualificationImmédiate   NANCY U18M2
# 3873    0         20         23  DisqualificationImmédiate   EPINAL U18M
#
#                  Joueur      Temps  \
# 3768          HIVERmalo   0.466667
# 3770       SCHERERrobin   0.983333
# 3772       KORDICjustin   1.516667
# 3774       SCHERERrobin   1.966667
# 3776      HURSTELnathan   3.183333
# ...                 ...        ...
# 3869                 NA  58.566667
# 3870         AHOSSIloic  59.333333
# 3871      GLOMETraphael  59.800000
# 3872  MUNOZBOUVIERrobin  60.000000
# 3873      DUHOUXbastien  60.000000
#
#                                       Full_Action
# 3768                                But HIVERmalo
# 3770                             But SCHERERrobin
# 3772                             But KORDICjustin
# 3774                             But SCHERERrobin
# 3776                            But HURSTELnathan
# ...                                           ...
# 3869                 TempsMortd'EquipeVisiteur NA
# 3870                               But AHOSSIloic
# 3871                            But GLOMETraphael
# 3872  DisqualificationImmédiate MUNOZBOUVIERrobin
# 3873      DisqualificationImmédiate DUHOUXbastien
#
# [106 rows x 13 columns]

# %% [markdown]
# # Load Video

# %%
lst =glob.glob('D:/Films perso/2022-10-15 Nancy-Epinal/*.MOD')
lst
# Out:
# ['D:/Films perso/2022-10-15 Nancy-Epinal\\Nancy-Epinal (1).MOD',
#  'D:/Films perso/2022-10-15 Nancy-Epinal\\Nancy-Epinal (10).MOD',
#  'D:/Films perso/2022-10-15 Nancy-Epinal\\Nancy-Epinal (11).MOD',
#  'D:/Films perso/2022-10-15 Nancy-Epinal\\Nancy-Epinal (12).MOD',
#  'D:/Films perso/2022-10-15 Nancy-Epinal\\Nancy-Epinal (3).MOD',
#  'D:/Films perso/2022-10-15 Nancy-Epinal\\Nancy-Epinal (5).MOD',
#  'D:/Films perso/2022-10-15 Nancy-Epinal\\Nancy-Epinal (6).MOD',
#  'D:/Films perso/2022-10-15 Nancy-Epinal\\Nancy-Epinal (8).MOD',
#  'D:/Films perso/2022-10-15 Nancy-Epinal\\Nancy-Epinal (9).MOD']

# %%
timedelta(minutes=2)
# Out:
# datetime.timedelta(seconds=120)

# %%
def analyse_video(f):
    video_dict={}
    # video_dict['item']= re.findall('\((\d+)\)',f)
    video_dict['file']=f 
    cap = cv.VideoCapture(f)
    # fps = cap.get(cv.CAP_PROP_FPS)      # OpenCV v2.x used "CV_CAP_PROP_FPS"
    # frame_count = int(cap.get(cv.CAP_PROP_FRAME_COUNT))
    # duration = frame_count/fps
    # print('fps = ' + str(fps))
    video_dict['fps']= cap.get(cv.CAP_PROP_FPS)      # OpenCV v2.x used "CV_CAP_PROP_FPS"
    video_dict['frame_count']=  int(cap.get(cv.CAP_PROP_FRAME_COUNT))
    video_dict['duration_sec']=video_dict['frame_count']/video_dict['fps']
    # print('number of frames = ' + str(frame_count))
    # print('duration (S) = ' + str(duration))
    video_dict['minutes']=int(video_dict['duration_sec']/60)
    video_dict['seconds']=int(video_dict['duration_sec']%60)
    # minu = int(duration/60)
    # seco = int(duration%60)
    # print('duration (M:S) = ' + str(minutes) + ':' + str(seconds))
    end_time = datetime.fromtimestamp(os.path.getmtime(f))
    # start_time = end_time -datetime(end_time.year,end_time.month,end_time.day,0,minutes,seconds)
    video_dict['start_time']=end_time -timedelta(minutes=video_dict['minutes'],seconds=video_dict['seconds'])
    video_dict['end_time']=datetime.fromtimestamp(os.path.getmtime(f))
    # print(f'File ending time : {end_time}') 
    # print(f'File starting time : {start_time}')
    cap.release()
    return video_dict

# %%
videos =  []
for v in lst:
    videos.append(analyse_video(v))
df = pd.DataFrame(videos)

# %%
df.sort_values(by='start_time', inplace=True)
df.reset_index(inplace=True)

# %%
df.loc[0,'Delta_Start_End']=df.loc[0,'end_time']-df.loc[0,'start_time']
df['Delta_Break']=timedelta(minutes=0)
for i in range(df.shape[0]-1):
    df.loc[i+1,'Delta_Start_End']=df.loc[i+1,'end_time']-df.loc[i+1,'start_time']
    df.loc[i+1,'Delta_Break']=df.loc[i+1,'start_time']-df.loc[i,'end_time']

# %%
df['T_start_cumul_forcé']=''
df['Comment']=''

# %%
def calc_cumul():
    df.loc[0,'T_start_cumul']=0
    for i in range(df.shape[0]-1):
        if df.loc[i+1,'T_start_cumul_forcé']!='':
            df.loc[i+1,'T_start_cumul']=df.loc[i+1,'T_start_cumul_forcé']
        else:
            df.loc[i+1,'T_start_cumul']=df.loc[i,'T_start_cumul']+df.loc[i,'Delta_Start_End'].seconds//60+df.loc[i,'Delta_Start_End'].seconds%60/100*100/60

# %%
calc_cumul()

# %%
# Detection mi-temps et forçage du temps 
for i in range(df.shape[0]-1):
    if (df.loc[i+1,'Delta_Break']>timedelta(minutes=8)):
        df.loc[i+1,'Comment']='Mi-temps'
        df.loc[i+1,'T_start_cumul_forcé']=30  
calc_cumul()

# %%
TM=[]
print('LISTE DES TEMPS MORT DU MATCH')
for i,l in df_m.iterrows():
    if 'TempsMort' in l.Action:
        TM.append([i,l.Temps,l.Action])
TM
# Out:
# LISTE DES TEMPS MORT DU MATCH
# [[3838, 21.116666666666667, "TempsMortd'EquipeRecevant"],
#  [3807, 41.21666666666667, "TempsMortd'EquipeRecevant"],
#  [3815, 43.3, "TempsMortd'EquipeVisiteur"],
#  [3869, 58.56666666666667, "TempsMortd'EquipeVisiteur"]]

# %%
# Detection temps mort et forçage du temps 
nb_TM=0
for i in range(df.shape[0]-1):
    if (df.loc[i+1,'Delta_Break']>timedelta(seconds=40)) and (df.loc[i+1,'Delta_Break']<timedelta(minutes=2)):
        nb_TM+=1
        df.loc[i+1,'Comment']='Temps Mort Potentiel'
        # df.loc[i+1,'T_start_cumul_forcé']=30  
calc_cumul()

# %%
nb_TM
# Out:
# 4

# %%
df
# Out:
#    index                                               file   fps  \
# 0      0  D:/Films perso/2022-10-15 Nancy-Epinal\Nancy-E...  25.0
# 1      4  D:/Films perso/2022-10-15 Nancy-Epinal\Nancy-E...  25.0
# 2      5  D:/Films perso/2022-10-15 Nancy-Epinal\Nancy-E...  25.0
# 3      6  D:/Films perso/2022-10-15 Nancy-Epinal\Nancy-E...  25.0
# 4      7  D:/Films perso/2022-10-15 Nancy-Epinal\Nancy-E...  25.0
# 5      8  D:/Films perso/2022-10-15 Nancy-Epinal\Nancy-E...  25.0
# 6      1  D:/Films perso/2022-10-15 Nancy-Epinal\Nancy-E...  25.0
# 7      2  D:/Films perso/2022-10-15 Nancy-Epinal\Nancy-E...  25.0
# 8      3  D:/Films perso/2022-10-15 Nancy-Epinal\Nancy-E...  25.0
#
#    frame_count  duration_sec  minutes  seconds          start_time  \
# 0        33096       1323.84       22        3 2022-10-15 18:38:19
# 1        14124        564.96        9       24 2022-10-15 19:01:38
# 2        10608        424.32        7        4 2022-10-15 19:23:32
# 3         7260        290.40        4       50 2022-10-15 19:30:50
# 4         3768        150.72        2       30 2022-10-15 19:37:14
# 5        24624        984.96       16       24 2022-10-15 19:41:08
# 6         4020        160.80        2       40 2022-10-15 19:58:48
# 7          792         31.68        0       31 2022-10-15 20:01:45
# 8          420         16.80        0       16 2022-10-15 20:02:54
#
#              end_time Delta_Start_End     Delta_Break T_start_cumul_forcé  \
# 0 2022-10-15 19:00:22 0 days 00:22:03 0 days 00:00:00
# 1 2022-10-15 19:11:02 0 days 00:09:24 0 days 00:01:16
# 2 2022-10-15 19:30:36 0 days 00:07:04 0 days 00:12:30                  30
# 3 2022-10-15 19:35:40 0 days 00:04:50 0 days 00:00:14
# 4 2022-10-15 19:39:44 0 days 00:02:30 0 days 00:01:34
# 5 2022-10-15 19:57:32 0 days 00:16:24 0 days 00:01:24
# 6 2022-10-15 20:01:28 0 days 00:02:40 0 days 00:01:16
# 7 2022-10-15 20:02:16 0 days 00:00:31 0 days 00:00:17
# 8 2022-10-15 20:03:10 0 days 00:00:16 0 days 00:00:38
#
#                 Comment  T_start_cumul
# 0                             0.000000
# 1  Temps Mort Potentiel      22.050000
# 2              Mi-temps      30.000000
# 3                            37.066667
# 4  Temps Mort Potentiel      41.900000
# 5  Temps Mort Potentiel      44.400000
# 6  Temps Mort Potentiel      60.800000
# 7                            63.466667
# 8                            63.983333
